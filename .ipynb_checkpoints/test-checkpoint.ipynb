# %% [markdown]
# Peter Mačuga
#
# Adam Šípka
#
# Podiel práce: 50/50
#
# Číslo datasetu: 30

# %%
import matplotlib.pyplot as plt
import pylab as py
import seaborn as sns
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.stats as sm_stats
import statsmodels.stats.api as sms
import scipy.stats as stats

# %%
file = "dataset/other_train.csv"
medical_data = pd.read_csv(file)

file = "dataset/personal_train.csv"
personal_data = pd.read_csv(file)

pd.set_option("display.max_columns", None) # pd.reset_option("max_columns")
medical_data.head()
# Out:
#    Unnamed: 0                 name  \
# 0           0  Christian Gustafson
# 1           1    Charles Gillespie
# 2           2          Milton Dube
# 3           3          Roy Paradis
# 4           4      Jonathan Spears
#
#                                              address  kurtosis_oxygen  \
# 0  67834 Kim Plaza Suite 620\r\nNew Desiree, KS 8...         6.123066
# 1  62025 Michael Turnpike\r\nSouth Stephaniemouth...         9.839099
# 2  91113 Pierce Pass Suite 424\r\nPort Alejandrab...         0.237147
# 3  01168 Stark Pine Apt. 583\r\nDavidville, IN 32044         9.420978
# 4  698 Cody Prairie Suite 415\r\nPort Jenniferche...         1.395169
#
#   pregnant  education-num    relationship  skewness_glucose  mean_glucose  \
# 0        f           13.0   Not-in-family         -0.015362    141.187500
# 1        f            9.0         Husband          0.672588    120.718750
# 2        f           10.0       Own-child         16.544542     34.640625
# 3        f            5.0   Not-in-family         -0.877518    136.148438
# 4        f            4.0       Own-child         20.564579     34.914062
#
#    std_oxygen  capital-gain  skewness_oxygen  kurtosis_glucose  \
# 0   29.136418           0.0        38.011933         -0.139766
# 1   16.569199           0.0       111.269661          0.257893
# 2   65.976393           0.0        -0.338388          3.799229
# 3   13.897067           0.0       123.388400         -0.053924
# 4   60.871138           0.0         1.019152          4.429704
#
#                                        personal_info      education    fnlwgt  \
# 0  Prof-specialty|United-States\r\r\nNever-marrie...      Bachelors  196912.0
# 1  Other-service|United-States\r\r\nMarried-civ-s...        HS-grad  230136.0
# 2  Sales|United-States\r\r\nNever-married -- Priv...   Some-college  165505.0
# 3  Handlers-cleaners|United-States\r\r\nDivorced ...            9th  215150.0
# 4           ?|United-States\r\r\nDivorced -- ?|White        7th-8th  200819.0
#
#    class  std_glucose  income  mean_oxygen  hours-per-week  capital-loss
# 0    0.0    47.682339   <=50K     5.114548            40.0           0.0
# 1    0.0    43.125713    >50K     2.163880            60.0           0.0
# 2    1.0    34.898230   <=50K    88.933946            20.0           0.0
# 3    0.0    61.442566   <=50K     2.379599            50.0           0.0
# 4    1.0    36.730868   <=50K    74.640468            84.0           0.0

# %%
# basic info about dataset
medical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3983 entries, 0 to 3982
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        3983 non-null   int64
#  1   name              3983 non-null   object
#  2   address           3983 non-null   object
#  3   kurtosis_oxygen   3974 non-null   float64
#  4   pregnant          3971 non-null   object
#  5   education-num     3579 non-null   float64
#  6   relationship      3961 non-null   object
#  7   skewness_glucose  3965 non-null   float64
#  8   mean_glucose      3963 non-null   float64
#  9   std_oxygen        3967 non-null   float64
#  10  capital-gain      3969 non-null   float64
#  11  skewness_oxygen   3975 non-null   float64
#  12  kurtosis_glucose  3968 non-null   float64
#  13  personal_info     3974 non-null   object
#  14  education         3971 non-null   object
#  15  fnlwgt            3967 non-null   float64
#  16  class             3962 non-null   float64
#  17  std_glucose       3968 non-null   float64
#  18  income            3969 non-null   object
#  19  mean_oxygen       3971 non-null   float64
#  20  hours-per-week    3970 non-null   float64
#  21  capital-loss      3970 non-null   float64
# dtypes: float64(14), int64(1), object(7)
# memory usage: 684.7+ KB

# %%
personal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3933 entries, 0 to 3932
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     3933 non-null   int64
#  1   name           3933 non-null   object
#  2   address        3933 non-null   object
#  3   age            3933 non-null   int64
#  4   sex            3933 non-null   object
#  5   date_of_birth  3933 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 184.5+ KB

# %%
# mean, median, standard deviation ...
medical_data.describe()
# Out:
#        Unnamed: 0  kurtosis_oxygen  education-num  skewness_glucose  \
# count  3983.00000      3974.000000    3579.000000       3965.000000
# mean   1991.00000         7.416322      12.547080          4.199644
# std    1149.93739         4.803833     322.343903          9.663219
# min       0.00000        -2.597872   -1600.000000         -1.755332
# 25%     995.50000         3.667526       9.000000         -0.119347
# 50%    1991.00000         7.780968      10.000000          0.371808
# 75%    2986.50000        10.260954      13.000000          2.078418
# max    3982.00000        34.539844    1600.000000         68.101622
#
#        mean_glucose   std_oxygen  capital-gain  skewness_oxygen  \
# count   3963.000000  3967.000000   3969.000000      3975.000000
# mean     101.295505    31.109754   1001.580751        91.371858
# std       33.546001    22.228906   6799.385942       108.339309
# min        6.187500     7.370432      0.000000        -1.976976
# 25%       87.757812    15.032694      0.000000        13.074440
# 50%      110.664062    20.554648      0.000000        68.629714
# 75%      124.140625    43.052135      0.000000       126.954629
# max      189.734375   110.642211  99999.000000      1191.000837
#
#        kurtosis_glucose         fnlwgt        class  std_glucose  mean_oxygen  \
# count       3968.000000    3967.000000  3962.000000  3968.000000  3971.000000
# mean           0.949064  189412.756995     0.254922    45.176099    18.421711
# std            1.608717  102953.580337     0.435872     7.596572    34.713003
# min           -1.641515   19214.000000     0.000000    25.695250     0.213211
# 25%            0.071484  117833.000000     0.000000    40.183354     2.067308
# 50%            0.310279  180869.000000     0.000000    45.888203     3.237458
# 75%            0.775953  235405.000000     1.000000    50.357111    12.604515
# max            8.069522  755858.000000     1.000000    91.206475   217.371238
#
#        hours-per-week  capital-loss
# count     3970.000000   3970.000000
# mean        40.306549     85.335264
# std         12.349879    402.217959
# min          1.000000      0.000000
# 25%         40.000000      0.000000
# 50%         40.000000      0.000000
# 75%         45.000000      0.000000
# max         99.000000   4356.000000

# %%
# mode
print(stats.mode(medical_data["mean_glucose"]))
print(stats.mode(medical_data["mean_oxygen"]))

print(stats.mode(medical_data["kurtosis_glucose"]))
print(stats.mode(medical_data["kurtosis_oxygen"]))

print(stats.mode(medical_data["skewness_glucose"]))
print(stats.mode(medical_data["skewness_oxygen"]))
# Out:
# ModeResult(mode=array([87.03125]), count=array([4]))
# ModeResult(mode=array([2.1187291]), count=array([5]))
# ModeResult(mode=array([-0.41742506]), count=array([2]))
# ModeResult(mode=array([0.74557927]), count=array([2]))
# ModeResult(mode=array([-0.3951294]), count=array([2]))
# ModeResult(mode=array([0.32635084]), count=array([2]))

# %%
# variance
print(np.var(medical_data["mean_glucose"]))
print(np.var(medical_data["mean_oxygen"]))

print(np.var(medical_data["kurtosis_glucose"]))
print(np.var(medical_data["kurtosis_oxygen"]))

print(np.var(medical_data["skewness_glucose"]))
print(np.var(medical_data["skewness_oxygen"]))
# Out:
# 1125.0502299640254
# 1204.6891359283454
# 2.5873178263574617
# 23.071006429194963
# 93.35424335845731
# 11734.453125808688

# %%
sns.boxplot(data = medical_data, x = "mean_glucose")
# Out:
# <AxesSubplot:xlabel='mean_glucose'>

# %%
sns.boxplot(data = medical_data, x = "mean_oxygen")
# Out:
# <AxesSubplot:xlabel='mean_oxygen'>

# %%
sns.boxplot(data = medical_data, x = "kurtosis_glucose")
# Out:
# <AxesSubplot:xlabel='kurtosis_glucose'>

# %%
sns.boxplot(data = medical_data, x = "kurtosis_oxygen")
# Out:
# <AxesSubplot:xlabel='kurtosis_oxygen'>

# %%
sns.boxplot(data = medical_data, x = "skewness_glucose")
# Out:
# <AxesSubplot:xlabel='skewness_glucose'>

# %%
sns.boxplot(data = medical_data, x = "skewness_oxygen")
# Out:
# <AxesSubplot:xlabel='skewness_oxygen'>

# %%
sns.displot(data = medical_data, x = "mean_glucose")

# %%
sns.displot(data = medical_data, x = "mean_oxygen")

# %%
sns.displot(data = medical_data, x = "kurtosis_glucose")

# %%
sns.displot(data = medical_data, x = "kurtosis_oxygen")

# %%
sns.displot(data = medical_data, x = "skewness_glucose")

# %%
sns.displot(data = medical_data, x = "skewness_oxygen")

# %% [markdown]
# ## Základný opis dát a ich charakteristika
#
# Súbor personal_train.cvs
# - 3933 záznamov
# - 6 stĺpcov:
#     - Unnamed: 0 (číslo riadku) - integer
#     - name (meno) - object/string
#     - address (adresa) - object/string
#     - age (vek) - integer
#     - sex (pohlavie) - object/string
#     - date_of_birth (dátum narodenia) - object/string
#
# Súbor other_train.cvs
# - 3983 záznamov
# - 22 stĺpcov:
#     - Unnamed: 0 (číslo riadku) - integer
#     - name (meno) - object/string
#     - address (adresa) - object/string
#     - kurtosis_oxygen (koeficient špicatosti pre hladinu kyslíka v krvi) - float
#     - pregnant (tehotný) - object/string
#     - education-num - float
#     - relationship - object/string
#     - skewness_glucose (koeficient asymetrie pre hladinu cukru v krvi) - float
#     - mean_glucose (priemerná hladina cukru v krvi) - float
#     - std_oxygen (štandardná odchýlka pre hladinu kyslíka v krvi) - float
#     - capital-gain - float
#     - skewness_oxygen (koeficient asymetrie pre hladinu kyslíka v krvi) - float
#     - kurtosis_glucose (koeficient špicatosti pre hladinu cukru v krvi) - float
#     - personal_info (osobné údaje) - object/string
#     - education (dosiahnuté vzdelanie) - object/string
#     - fnlwgt - float
#     - class (prítomnosť ochorenia) - float
#     - std_glucose (štandardná odchýlka pre hladinu cukru v krvi) - float
#     - income (ročný príjem) - object/string
#     - mean_oxygen (priemerná hladina kyslíka v krvi) - float
#     - hours-per-week - float
#     - capital-loss - float
#
# štatistické údaje pre priemernú hladinu cukru v krvi:
# - priemer = 101.295
# - medián = 110.664
# - smerodajná odchýlka = 33.546
# - variancia = 1125.050
# - minimum = 6.187
# - maximum = 189.734
#
# štatistické údaje pre koeficient špicatosti pre hladinu cukru v krvi:
# - priemer = 0.949
# - medián = 0.310
# - smerodajná odchýlka = 1.608
# - variancia = 2.587
# - minimum = -1.641
# - maximum = 8.069
#
# štatistické údaje pre koeficient asymetrie pre hladinu cukru v krvi:
# - priemer = 4.199
# - medián = 0.371
# - smerodajná odchýlka = 9.663
# - variancia = 93.354
# - minimum = -1.755
# - maximum = 68.101
#
# štatistické údaje pre priemernú hladinu kyslíka v krvi
# - priemer = 18.421
# - medián = 3.237
# - smerodajná odchýlka = 34.713
# - variancia = 1204.689
# - minimum = 0.213
# - maximum = 217.371
#
# štatistické údaje pre koeficient špicatosti pre hladinu kyslíka v krvi:
# - priemer = 7.416
# - medián = 7.780
# - smerodajná odchýlka = 4.803
# - variancia = 23.071
# - minimum = -2.597
# - maximum = 34.539
#
# štatistické údaje pre koeficient asymetrie pre hladinu kyslíka v krvi:
# - priemer = 91.371
# - medián = 68.629
# - smerodajná odchýlka = 108.339
# - variancia = 11734.453
# - minimum = -1.976
# - maximum = 1191.000

# %% [markdown]
# ## Párová analýza

# %%
# Heatmapa ktora zobrazuje korelacie medzi vsetkymi stlpcami datasetu
# Zaporna korelácia je vyjadrena zmavsou farbou,
# Pozitivna korelacia je vyjadrena svetlou
# Ziadna korelacia je vyjadrena cervou
sns.heatmap(medical_data.corr())
# Out:
# <AxesSubplot:>

# %%
# Spojene dáta z personal datasetu a medical datasetu, dovolí nám to robiť párovú analýzu na doležitých faktoroch ako pohlavie a vek
complete_data = pd.merge(personal_data, medical_data, on="name")
complete_data = complete_data.drop(columns=['Unnamed: 0_x', 'address_x', 'Unnamed: 0_y', 'address_y'])
complete_data.head(10)
# Out:
#                    name  age      sex date_of_birth  kurtosis_oxygen pregnant  \
# 0       Roscoe Bohannon   64   Female    1955-08-04         5.726570        f
# 1          Ernest Kline   45     Male    1974-05-17        12.577851        f
# 2       Harold Hendriks   42     Male    1977-01-13         4.328753        f
# 3        Randy Baptiste   61   Female    28/12/1957         1.893722        f
# 4       Anthony Colucci   57     Male    1962-07-07        10.448488        f
# 5          Ronald Lange   62   Female    1957-03-16         9.133436        f
# 6         Boyd Eiselein   76     Male    1943/07/04         6.062392        f
# 7         Raymond Smith   35   Female    1984-05-13         7.263724    FALSE
# 8         Harold Miller   48     Male    1971-05-10        13.071995        f
# 9  Charles Czachorowski   32   Female    1986-11-13         5.661746        f
#
#    education-num     relationship  skewness_glucose  mean_glucose  std_oxygen  \
# 0           13.0    Not-in-family          4.056839     83.148438   30.577686
# 1           13.0          Husband         -0.301184    118.804688   13.993434
# 2            6.0          Husband          0.246588    110.687500   30.566874
# 3            9.0   Other-relative          3.566892     75.171875   64.442520
# 4           14.0          Husband         -0.192537    110.492188   13.826013
# 5            9.0    Not-in-family         -0.477533    109.664062   17.874913
# 6           10.0    Not-in-family          2.179898     94.218750   29.733092
# 7            9.0    Not-in-family         -0.140353    136.882812   24.061932
# 8            9.0          Husband          0.420468    117.632812   12.320204
# 9           10.0        Unmarried          0.421060    132.273438   31.119534
#
#    capital-gain  skewness_oxygen  kurtosis_glucose  \
# 0           0.0        34.052638          1.522565
# 1           0.0       188.371439          0.083254
# 2           0.0        19.292524          0.332310
# 3           0.0         2.244264          1.804847
# 4           0.0       140.560188         -0.043437
# 5           0.0        93.991725          0.289527
# 6           0.0        37.529703          1.097079
# 7           0.0        53.468944         -0.018763
# 8           0.0       204.455042          0.133825
# 9           0.0        32.331305         -0.338099
#
#                                        personal_info      education    fnlwgt  \
# 0  Adm-clerical|United-States\r\r\nnan -- Federal...      Bachelors  124076.0
# 1  Sales|United-States\r\r\nMarried-civ-spouse --...      Bachelors  383365.0
# 2  Handlers-cleaners|Mexico\r\r\nMarried-civ-spou...           10th  272913.0
# 3  Sales|United-States\r\r\nNever-married -- Priv...        HS-grad  509048.0
# 4  Exec_managerial|United-States\r\r\nMarried-civ...        Masters  368797.0
# 5  Adm-clerical|United-States\r\r\nDivorced -- Pr...        HS-grad  156815.0
# 6  Sales|United-States\r\r\nNever-married -- Priv...   Some-college  194247.0
# 7  Sales|United-States\r\r\nWidowed -- Private|White        HS-grad  118303.0
# 8  Sales|Germany\r\r\nMarried-civ-spouse -- Self-...        HS-grad  190450.0
# 9  Exec-managerial|United-States\r\r\n?? -- Priva...   Some-college  180807.0
#
#    class  std_glucose  income  mean_oxygen  hours-per-week  capital-loss
# 0    1.0    38.294519   <=50K     6.010033            40.0           0.0
# 1    0.0    50.890363    >50K     1.563545            70.0           0.0
# 2    0.0    47.697574   <=50K     7.668060            30.0           0.0
# 3    1.0    42.486415   <=50K    31.560201            37.0           0.0
# 4    0.0    52.000450    >50K     2.032609            60.0        1977.0
# 5    0.0    56.167339   <=50K     2.418060            40.0           0.0
# 6    1.0    42.890110   <=50K     5.266722            40.0           0.0
# 7    0.0    52.272068    >50K     3.470736            35.0           0.0
# 8    0.0    44.345214   <=50K     1.229933            40.0           0.0
# 9    0.0    43.702602   <=50K     5.749164            40.0           0.0

# %%
# Graf medzi kurtosis oxygen a kurtosis glucose
# vidime velmi silnu negativnu korelaciu
df_selected = complete_data[['kurtosis_oxygen', 'kurtosis_glucose', 'class', 'age']]
sns.pairplot(df_selected, hue='class')

# %%
df_selected = complete_data[['mean_oxygen', 'mean_glucose', 'class', 'age']]
sns.pairplot(df_selected, hue='class')

# %%
df_selected = complete_data[['kurtosis_oxygen', 'kurtosis_glucose', 'sex', 'age']]
sns.pairplot(df_selected, hue='sex')

# %%
df_selected = complete_data[['std_oxygen', 'std_glucose', 'sex', 'age']]
sns.pairplot(df_selected, hue='sex')

# %% [markdown]
# ## Záver párovej analýzy
#
# Heatmapa na začiatku kapitoly ukazuje korelácie všetkých stĺpcov s všetkými stĺpcami. Svetlá farba vyjadruje pozitívnu koreláciu, tmavá farba negatívnu a svelo červená žiadnu koreláciu.
#
# Z pairplotov je vidno koreláciu medzi stupňami glukózy v krvi a vekom, stupňami kyslíka v krvi a stĺpcom menom class. Z tohto je možné predpokladať že class je istý typ choroby, ktorý zapríčiňuje vysoké levely cukru v krvi. Taktiež vieme vyčítať, že ľudia postihnutí touto chorobou majú všeobecne menšie stupne kyslíku ako tí, ktorí sú zdraví. Zo závisloti veku vidíme, že najviacej chorých je vo vekovej kategoríi 50-60 rokov.
#
# Z pairplotu, ktoré zvýreznovali pohlavie sme nenašiel žiadne korelácie medzi levelmi kyslíku alebo glukózy v krvi s pohlavím testovaných.

# %% [markdown]
# ## Hypotézy
#
# ### Hypotéza č.1 :
#
# Ľudia nad 45 rokov majú väčsiu šancu dostať cukrovku.

# %%
hypothesis1_set = complete_data[['age', 'mean_glucose','class']]
hypothesis1_set = hypothesis1_set.assign(bool = hypothesis1_set['age' ] > 45)

# %%
sns.catplot(x="bool", y="mean_glucose",hue="class", kind="box",
                 data=hypothesis1_set)

# %% [markdown]
# ### Záver hypotézy č. 1:
#
# Ako môžme vidieť na grafe, levely mean_glucose sú medzi dvomi vekovými kategóriami podobné pri chorých aj pri zdravých, teda hypotéza 1 nie je potvrdená.

# %% [markdown]
# ### Hypotéza č.2 :
# ​
# Muži medzi rokmi 35 - 40 rokov majú nižšie stupňe glukózy v krvi ako ženy.

# %%
hypothesis2_set = complete_data[['age', 'mean_glucose','sex']]
hypothesis2_set = hypothesis2_set[hypothesis2_set['age' ] >= 35]
hypothesis2_set = hypothesis2_set[hypothesis2_set['age' ] <= 40]

hypothesis2_set_men = hypothesis2_set[hypothesis2_set["sex"] == " Male"]
hypothesis2_set_women =  hypothesis2_set[hypothesis2_set["sex"] == " Female"]

# %%
sns.boxplot(x="age", y="mean_glucose", hue="sex",
                 data=hypothesis2_set, dodge=False,)
# Out:
# <AxesSubplot:xlabel='age', ylabel='mean_glucose'>

# %%
sns.boxplot(x="sex", y="mean_glucose",
                 data=hypothesis2_set, dodge=False,)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='mean_glucose'>

# %% [markdown]
# ### Záver hypotézy č. 2:
#
# Ako je vidno na grafoch, medzi jednotlivými rokmi je vidno nejake rozdiely v obsahu krvi medzi ženským a mužským pohlavím, avšak v celom 5 ročnom rozmedzí tam veľký rozdiel nie je. Preto teda táto hypotéza bola vyvrátená

# %% [markdown]
# ## Identifikácia problémov v dátach
#
# V momentálnom stave dáta nie sú vhodné na ďalšie spracovanie, vyskytujú sa v nich problémy, ktoré nám v tom bránia.
# V tejto časti dané problémy identifikujeme a navrhneme ich riešenie.
#
# Dáta sú v oboch setoch v tabuľkovej podobe a mená stĺpcov sú až na dve výnimky dostatočne opisujúce. Stĺpec "fnlwgt"
# by nemal byť pomenovaný v skratkovej podobe, keďže všetky ostatné stĺpce majú neskratkové pomenovanie. Bolo by vhodné
# premenovať ho na "final_weight". Stĺpec "class" bude taktiež nutné premenovať, z dôvodu, že je to rezervovaný keyword
# v Pythone. Tiež by bolo vhodné zmeniť jeho dátový typ z float na bool, keďže v ňom nastávajú len hodnoty 1 a 0.
#
# Oba sety obsahujú stĺpec "Unnamed: 0", ktorý symbolizuje poradie riadkov v tabuľke. Na čísla riadkov nie je nutné
# mať špecifický stĺpec, túto možnosť poskytuje knižnica pandas automaticky. V prípade, že by došlo k zmene poradia
# záznamov, bolo by taktiež nutné meniť hodnoty v tomto stĺpci, čo je vlastne zbytočné, lebo pandas vypíše poradové
# číslo správne, aj bez nášho zásahu. Z každého setu môžeme teda celý stĺpec "Unnamed: 0" odstrániť.
#
# Hodnoty v stĺpci "education-num" odkazujú na hodnoty v stĺpci "education", čiže celý stĺpec "education-num" nám podáva
# rovnakú informáciu ako stĺpec "education". Z tohto dôvodu ho môžeme z dátového setu odstrániť. Ak by sme toto nechceli
# spraviť, tak je nutné niektoré hodnoty upraviť, pretože sú chybné a majú pripísané nuly navyše. Unikátných hodnôt v
# "education" je 16, takže stĺpec "education-num" by ich mal obsahovať rovnako.
#
# Taktiež pri stĺpcoch, ktoré majú len celočíselné hodnoty (capital-gain, fnlwgt, hours-per-week, capital-loss)
# by bolo vhodné zmeniť dátový typ z float na integer.

# %%
personal_data.nunique()
# Out:
# Unnamed: 0       3933
# name             3933
# address          3933
# age                84
# sex                 2
# date_of_birth    3717
# dtype: int64

# %%
medical_data.nunique()
# Out:
# Unnamed: 0          3983
# name                3933
# address             3933
# kurtosis_oxygen     3933
# pregnant               6
# education-num         46
# relationship           6
# skewness_glucose    3932
# mean_glucose        3344
# std_oxygen          3932
# capital-gain          75
# skewness_oxygen     3933
# kurtosis_glucose    3932
# personal_info       1078
# education             16
# fnlwgt              3643
# class                  2
# std_glucose         3931
# income                 2
# mean_oxygen         3316
# hours-per-week        74
# capital-loss          46
# dtype: int64

# %%
print(sum(medical_data.duplicated(["name", "address"])))
print(sum(medical_data.duplicated(["name", "address", "personal_info"])))
print(sum(medical_data.duplicated(["name", "address", "personal_info", "education"])))
# Out:
# 50
# 41
# 32

# %%
medical_data[medical_data.duplicated(["name", "address", "personal_info", "education"])]
# Out:
#       Unnamed: 0                name  \
# 678          678        Matthew Dias
# 724          724       Willie Gerace
# 1180        1180          Adam Baugh
# 1238        1238      Chester Holmes
# 1267        1267    Franklin Vergara
# 1489        1489         Byron Saari
# 1679        1679     Sean Richardson
# 1763        1763      Joseph Hensley
# 1862        1862       Vernon Godwin
# 1960        1960      Wallace Street
# 2005        2005       David Sanders
# 2170        2170       Carlos Coffee
# 2233        2233     Jayson Arcement
# 2257        2257    Eddie Kalinowski
# 2774        2774     Tracey Robinson
# 2848        2848     Robert Stanfill
# 2944        2944       Dennis Martin
# 2955        2955           Guy Davis
# 3019        3019     Rich Strickland
# 3098        3098          Ted Fields
# 3103        3103       Curtis Arzola
# 3170        3170        Thomas Bates
# 3257        3257      Anthony Kruger
# 3527        3527         Russell Lee
# 3683        3683  Theodore Rodibaugh
# 3688        3688      Richard Salada
# 3691        3691       Charles Bowen
# 3746        3746     William Paddock
# 3795        3795       Thomas Rivers
# 3826        3826           Earl Ross
# 3854        3854         Bret Barnes
# 3951        3951        Donnie Trout
#
#                                                 address  kurtosis_oxygen  \
# 678   3371 Natasha Stream Apt. 300\r\nHillport, HI 7...         1.015688
# 724                  Unit 0472 Box 3935\r\nDPO AA 56086         5.266318
# 1180  285 Rodney Center Suite 670\r\nGregorystad, NH...        16.155303
# 1238  720 Harris Turnpike Suite 732\r\nEast Sierra, ...         4.886473
# 1267  178 Watson Ramp Apt. 479\r\nWest Samantha, AK ...              NaN
# 1489      520 Amanda Path\r\nPort Loriborough, AR 42069         7.880256
# 1679  741 Christopher Squares\r\nWest Shirleystad, W...         5.705468
# 1763       524 Michelle Harbor\r\nNew Michele, KS 82465         5.560734
# 1862  9638 Mario Ford Suite 929\r\nNorth Paulfurt, M...         2.167198
# 1960          9909 John Creek\r\nEast Heather, NY 31266         5.700616
# 2005          4780 Joseph Mount\r\nJonesshire, RI 87231        13.011220
# 2170           87970 Eric Trail\r\nReginaside, RI 41013         6.557774
# 2233                 PSC 8771, Box 2055\r\nAPO AA 63519         1.432435
# 2257  468 Robertson Street Apt. 154\r\nCharlottevill...              NaN
# 2774  665 Alexander Shores Apt. 798\r\nPort Charles,...         9.509217
# 2848  1195 Danielle Park Suite 277\r\nWilliamsmouth,...         4.610877
# 2944    1100 Andrew Fork Apt. 645\r\nNew Ryan, CA 48399         6.600239
# 2955  818 Garcia Square Suite 465\r\nWest Kellyland,...         2.541429
# 3019       038 Kyle Ridge\r\nPort Deniseville, WY 90345              NaN
# 3098  2670 Davis Cliffs Suite 803\r\nGreenview, WV 0...        17.011557
# 3103            2903 Jones Crest\r\nHallmouth, CA 81449         7.881231
# 3170                 PSC 1078, Box 6024\r\nAPO AE 38144              NaN
# 3257         24029 White Tunnel\r\nShannonton, KS 80428         6.182854
# 3527       51705 Delacruz Ferry\r\nTorresside, KY 97154         7.669263
# 3683          55818 Jacob Haven\r\nBrendafurt, WI 38772         2.978489
# 3688  28481 David Cliffs Suite 023\r\nMckinneyhaven,...         7.099364
# 3691         1314 Lewis Ville\r\nLewischester, IA 69543         3.663287
# 3746    851 Hensley Springs\r\nEast Taraburgh, SC 56274        11.085472
# 3795          7655 Cohen Ferry\r\nWest Andrew, NY 77223        13.212439
# 3826        4694 Williams Islands\r\nEricberg, NE 76541        14.285598
# 3854  73014 Carlson Bypass Suite 457\r\nNicholasburg...         1.128142
# 3951  74491 Summer Streets Suite 908\r\nPort Nancyha...         6.026228
#
#      pregnant  education-num     relationship  skewness_glucose  mean_glucose  \
# 678         f           14.0              NaN         10.504677     37.328125
# 724         f            NaN              NaN          0.113315    119.382812
# 1180        f            NaN              NaN          0.008937    147.070312
# 1238        f           14.0          Husband          0.188801    131.914062
# 1267        f            9.0              NaN          3.412679     88.570312
# 1489        f            7.0        Own-child          0.902591    104.492188
# 1679        f            NaN        Own-child         -0.136844    114.539062
# 1763        t           10.0    Not-in-family         -0.174616    129.171875
# 1862        f           13.0    Not-in-family          2.470420     86.382812
# 1960        f           10.0          Husband               NaN    138.765625
# 2005     TRUE            NaN        Unmarried          0.164212    104.593750
# 2170      NaN           10.0    Not-in-family          0.266472           NaN
# 2233        f           16.0              NaN         11.012415     62.960938
# 2257      NaN            9.0        Unmarried         -0.344998    134.101562
# 2774      NaN         1200.0          Husband          0.986711    111.554688
# 2848        f           13.0          Husband               NaN     61.460938
# 2944        f            6.0    Not-in-family          1.033181    109.781250
# 2955        f            9.0        Unmarried         -0.334631    120.453125
# 3019        f            9.0          Husband         -0.395129           NaN
# 3098    FALSE            7.0          Husband               NaN           NaN
# 3103        t            9.0        Unmarried         -0.312486    124.914062
# 3170        f            NaN   Other-relative          0.682166           NaN
# 3257      NaN           10.0              NaN         -0.265950    136.117188
# 3527        f            5.0        Own-child          0.984387    122.476562
# 3683        f           14.0          Husband               NaN     42.976562
# 3688        f            7.0    Not-in-family          1.544753           NaN
# 3691      NaN            3.0          Husband          5.557122     72.054688
# 3746        f            9.0    Not-in-family          0.895623    110.070312
# 3795        f            6.0              NaN         -0.222749    109.453125
# 3826        f            9.0          Husband          1.205499    103.390625
# 3854        F            6.0        Unmarried         28.060145     28.343750
# 3951        f            9.0        Own-child          0.060912    106.718750
#
#       std_oxygen  capital-gain  skewness_oxygen  kurtosis_glucose  \
# 678    50.972282           NaN         0.495303          3.217384
# 724    29.767589           0.0        28.299804          0.133799
# 1180         NaN           0.0       297.847944         -0.417425
# 1238   37.953457           0.0        23.276103         -0.071573
# 1267   12.610148           0.0       210.857105          0.666299
# 1489         NaN           0.0        70.134399          0.290824
# 1679   26.479784           0.0        37.411527          0.208169
# 1763   34.033077           0.0        29.891930          0.133561
# 1862   59.924696           0.0         3.483176          1.373406
# 1960         NaN           0.0        33.735699          0.070280
# 2005   12.207188           NaN       210.055435          0.425018
# 2170         NaN           0.0        45.739782          0.264827
# 2233   65.572064           0.0         1.130669          2.622389
# 2257   12.020265           0.0              NaN         -0.122879
# 2774   19.855912           0.0        95.725134               NaN
# 2848         NaN           0.0              NaN          2.539502
# 2944   17.753278           0.0        55.816490          0.537863
# 2955   51.210491           0.0              NaN         -0.049047
# 3019         NaN           0.0       103.261706         -0.095445
# 3098    9.914319           0.0       379.587558         -0.076598
# 3103   21.543269           0.0        69.773978          0.004720
# 3170         NaN           0.0       125.782096          0.326218
# 3257   26.149560           0.0        41.945047          0.001149
# 3527   24.140423           0.0        61.494198          0.284663
# 3683   54.331824           0.0         7.470024               NaN
# 3688         NaN           0.0        52.461228               NaN
# 3691   42.820002           0.0        13.102997          1.649153
# 3746   13.524171           0.0       151.951658          0.210934
# 3795   11.170976           0.0       245.080261          0.090754
# 3826   10.583665           0.0       290.415072          0.253561
# 3854   71.163285           0.0         0.326351          4.818365
# 3951   29.929925           0.0        38.468864          0.483138
#
#                                           personal_info      education  \
# 678   Prof-specialty|United-States\r\r\nMarried-civ-...        Masters
# 724   Adm_clerical|United-States\r\r\n?? -- Self-emp...   Some-college
# 1180  Machine-op-inspct|United-States\r\r\nMarried-c...           11th
# 1238  Protective-serv|United-States\r\r\nMarried-civ...            NaN
# 1267  Craft-repair|United-States\r\r\nNever-married ...        HS-grad
# 1489  Craft-repair|Haiti\r\r\nNever-married -- Priva...           11th
# 1679  Prof_specialty|United-States\r\r\nNever-marrie...      Bachelors
# 1763  Other-service|United-States\r\r\nNever-married...   Some-college
# 1862  Handlers-cleaners|United-States\r\r\nNever-mar...      Bachelors
# 1960  Other-service|United-States\r\r\nMarried-civ-s...   Some-college
# 2005  Machine-op-inspct|United-States\r\r\nWidowed -...        5th-6th
# 2170  Other-service|United-States\r\r\nNever-married...   Some-college
# 2233  Adm-clerical|United-States\r\r\nNever-married ...      Doctorate
# 2257  Adm-clerical|United-States\r\r\nSeparated -- P...        HS-grad
# 2774  Transport-moving|United-States\r\r\nMarried-ci...     Assoc-acdm
# 2848  Farming-fishing|United-States\r\r\nMarried-civ...      Bachelors
# 2944  Sales|United-States\r\r\nNever-married -- Priv...           10th
# 2955  Other-service|United-States\r\r\nDivorced -- P...        HS-grad
# 3019  Machine-op-inspct|United-States\r\r\nMarried-c...        HS-grad
# 3098  Craft-repair|United-States\r\r\nMarried-civ-sp...           11th
# 3103  Sales|United-States\r\r\nDivorced -- Private|W...        HS-grad
# 3170  Sales|United-States\r\r\nNever-married -- priv...        HS-grad
# 3257  Other-service|?\r\r\nNever-married -- Private|...   Some-college
# 3527  Craft-repair|United-States\r\r\nNever-married ...            9th
# 3683  Exec-managerial|United-States\r\r\nMarried-civ...        Masters
# 3688  Other-service|United-States\r\r\nDivorced -- P...           11th
# 3691  Transport-moving|Mexico\r\r\nnan -- Private|White        5th-6th
# 3746  Other-service|United-States\r\r\nNever-married...        HS-grad
# 3795      ?|United-States\r\r\nNever-married -- ?|White           10th
# 3826  Machine-op-inspct|United-States\r\r\nMarried-c...        HS-grad
# 3854  Other-service|United-States\r\r\nWidowed -- Pr...           10th
# 3951  Adm_clerical|United-States\r\r\nNever-married ...        HS-grad
#
#         fnlwgt  class  std_glucose  income  mean_oxygen  hours-per-week  \
# 678        NaN    1.0    43.897806   <=50K   107.102007            55.0
# 724    71676.0    NaN          NaN     NaN     6.417224             1.0
# 1180  167065.0    0.0    45.582032     NaN     0.820234             NaN
# 1238  186539.0    0.0    44.490172    >50K     8.064381            40.0
# 1267   36275.0    0.0    33.858779   <=50K          NaN             NaN
# 1489  267034.0    0.0    40.074929   <=50K          NaN            40.0
# 1679  184589.0    0.0    51.280616   <=50K     5.801839            21.0
# 1763  149637.0    0.0    51.540201     NaN          NaN            40.0
# 1862  202046.0    1.0    46.733640   <=50K    27.238294            40.0
# 1960  123218.0    NaN    54.564968   <=50K     5.337793            40.0
# 2005       NaN    NaN    52.058777   <=50K     1.454013            40.0
# 2170  213385.0    0.0    48.416223   <=50K     4.383779            20.0
# 2233  220754.0    NaN    33.977337     NaN    48.867057            40.0
# 2257  228406.0    0.0    52.811404   <=50K     2.128763            40.0
# 2774  498325.0    NaN    40.337600   <=50K     2.360368            50.0
# 2848  249935.0    NaN    33.785376   <=50K     9.411371            60.0
# 2944  156822.0    0.0    40.253870   <=50K     3.626254            25.0
# 2955   83727.0    0.0          NaN   <=50K    18.691472            48.0
# 3019  175127.0    0.0    48.568711   <=50K          NaN            40.0
# 3098  259688.0    NaN    52.188426   <=50K     1.085284            50.0
# 3103   29059.0    0.0    47.858520   <=50K     3.724916            25.0
# 3170  194901.0    0.0    42.375426   <=50K     1.753344            40.0
# 3257  120691.0    NaN    50.573526     NaN     5.474080            35.0
# 3527   25955.0    0.0    41.549474   <=50K     3.428930             NaN
# 3683  119098.0    1.0    30.032395   <=50K    18.101171            40.0
# 3688  187969.0    0.0          NaN   <=50K     3.816054             NaN
# 3691       NaN    1.0    37.433964   <=50K    12.616221            40.0
# 3746  195985.0    0.0    40.339610     NaN          NaN            50.0
# 3795  634226.0    0.0    50.376994   <=50K     1.645485            17.0
# 3826  136081.0    0.0    38.801223   <=50K     1.484114            40.0
# 3854       NaN    NaN    31.814019   <=50K    57.377090            40.0
# 3951       NaN    1.0    48.599919   <=50K     6.269231            40.0
#
#       capital-loss
# 678            0.0
# 724         1944.0
# 1180           0.0
# 1238           NaN
# 1267           0.0
# 1489           0.0
# 1679           0.0
# 1763           NaN
# 1862        2001.0
# 1960           NaN
# 2005           0.0
# 2170           0.0
# 2233           0.0
# 2257           0.0
# 2774           NaN
# 2848           0.0
# 2944        1762.0
# 2955           0.0
# 3019           0.0
# 3098           0.0
# 3103        2754.0
# 3170           0.0
# 3257           0.0
# 3527           0.0
# 3683           NaN
# 3688           0.0
# 3691           0.0
# 3746           0.0
# 3795           0.0
# 3826        2051.0
# 3854           0.0
# 3951           0.0

# %% [markdown]
# Vidíme, že súbor personal_data určite neobsahuje duplikáty, počet všetkých záznamov je 3933 a počet unikátnych hodnôt
# pre meno a adresu je rovnaký. Každý záznam teda môžeme priradiť k jednému človeku. V súbore medical_data sa duplikáty
# už vyskytujú, vidíme, že počet unikátnych hodnôt pre meno a adresu je 3933, zatiaľ čo počet všetkých hodnôt je 3983.
# Ak záznam definitívne označíme za duplicitný, môžeme ho z dátoveho setu odstrániť. Predtým je ale nutné overiť, či sa
# skutočne jedná o duplikát.
#
# 100% duplicitné riadky sa v súbore nevyskytujú, rovnaké hodnoty nadobúdajú len v niektorých stĺpcoch. Počet riadkov, kde
# nie je unikátne meno a adresa je 50, ale ak zahrnieme aj stĺpec personal_info, tak sa zníži na 41. Zahrnutím stĺpca
# education klesne na 32. Treba vybrať stĺpce, podľa ktorých budeme určovať, či ide o duplikát a či nie. Zisťovať len
# podľa stĺpcov name a address nie je vhodné, keďže na rovnakej adrese môžu bývať aj dvaja ľudia s rovnakým menom. Bolo by
# vhodné pridať viacej stĺpcov, ktoré nám pomôžu zistiť, či je daný záznam skutočne duplikátom. Na to môžeme použiť
# napríklad stĺpec personal_info, ktorý obsahuje rôzne údaje, ako napríklad zamestnanie a rodinný stav. Vďaka tomu vieme
# povedať, že daný riadok sa vzťahuje na rozdielnu osobu a nie je duplicitný.

# %%
medical_data.pregnant.unique()
# Out:
# array(['f', 'FALSE', 'F', 'TRUE', 'T', 't', nan], dtype=object)

# %%
medical_data.nunique()
# Out:
# Unnamed: 0          3983
# name                3933
# address             3933
# kurtosis_oxygen     3933
# pregnant               6
# education-num         46
# relationship           6
# skewness_glucose    3932
# mean_glucose        3344
# std_oxygen          3932
# capital-gain          75
# skewness_oxygen     3933
# kurtosis_glucose    3932
# personal_info       1078
# education             16
# fnlwgt              3643
# class                  2
# std_glucose         3931
# income                 2
# mean_oxygen         3316
# hours-per-week        74
# capital-loss          46
# dtype: int64

# %%
print(sum(medical_data.duplicated(["name", "address"])))
print(sum(medical_data.duplicated(["name", "address", "personal_info"])))
print(sum(medical_data.duplicated(["name", "address", "personal_info", "education"])))
# Out:
# 50
# 41
# 32

# %%
medical_data[medical_data.duplicated(["name", "address", "personal_info", "education"])]
# Out:
#       Unnamed: 0                name  \
# 678          678        Matthew Dias
# 724          724       Willie Gerace
# 1180        1180          Adam Baugh
# 1238        1238      Chester Holmes
# 1267        1267    Franklin Vergara
# 1489        1489         Byron Saari
# 1679        1679     Sean Richardson
# 1763        1763      Joseph Hensley
# 1862        1862       Vernon Godwin
# 1960        1960      Wallace Street
# 2005        2005       David Sanders
# 2170        2170       Carlos Coffee
# 2233        2233     Jayson Arcement
# 2257        2257    Eddie Kalinowski
# 2774        2774     Tracey Robinson
# 2848        2848     Robert Stanfill
# 2944        2944       Dennis Martin
# 2955        2955           Guy Davis
# 3019        3019     Rich Strickland
# 3098        3098          Ted Fields
# 3103        3103       Curtis Arzola
# 3170        3170        Thomas Bates
# 3257        3257      Anthony Kruger
# 3527        3527         Russell Lee
# 3683        3683  Theodore Rodibaugh
# 3688        3688      Richard Salada
# 3691        3691       Charles Bowen
# 3746        3746     William Paddock
# 3795        3795       Thomas Rivers
# 3826        3826           Earl Ross
# 3854        3854         Bret Barnes
# 3951        3951        Donnie Trout
#
#                                                 address  kurtosis_oxygen  \
# 678   3371 Natasha Stream Apt. 300\r\nHillport, HI 7...         1.015688
# 724                  Unit 0472 Box 3935\r\nDPO AA 56086         5.266318
# 1180  285 Rodney Center Suite 670\r\nGregorystad, NH...        16.155303
# 1238  720 Harris Turnpike Suite 732\r\nEast Sierra, ...         4.886473
# 1267  178 Watson Ramp Apt. 479\r\nWest Samantha, AK ...              NaN
# 1489      520 Amanda Path\r\nPort Loriborough, AR 42069         7.880256
# 1679  741 Christopher Squares\r\nWest Shirleystad, W...         5.705468
# 1763       524 Michelle Harbor\r\nNew Michele, KS 82465         5.560734
# 1862  9638 Mario Ford Suite 929\r\nNorth Paulfurt, M...         2.167198
# 1960          9909 John Creek\r\nEast Heather, NY 31266         5.700616
# 2005          4780 Joseph Mount\r\nJonesshire, RI 87231        13.011220
# 2170           87970 Eric Trail\r\nReginaside, RI 41013         6.557774
# 2233                 PSC 8771, Box 2055\r\nAPO AA 63519         1.432435
# 2257  468 Robertson Street Apt. 154\r\nCharlottevill...              NaN
# 2774  665 Alexander Shores Apt. 798\r\nPort Charles,...         9.509217
# 2848  1195 Danielle Park Suite 277\r\nWilliamsmouth,...         4.610877
# 2944    1100 Andrew Fork Apt. 645\r\nNew Ryan, CA 48399         6.600239
# 2955  818 Garcia Square Suite 465\r\nWest Kellyland,...         2.541429
# 3019       038 Kyle Ridge\r\nPort Deniseville, WY 90345              NaN
# 3098  2670 Davis Cliffs Suite 803\r\nGreenview, WV 0...        17.011557
# 3103            2903 Jones Crest\r\nHallmouth, CA 81449         7.881231
# 3170                 PSC 1078, Box 6024\r\nAPO AE 38144              NaN
# 3257         24029 White Tunnel\r\nShannonton, KS 80428         6.182854
# 3527       51705 Delacruz Ferry\r\nTorresside, KY 97154         7.669263
# 3683          55818 Jacob Haven\r\nBrendafurt, WI 38772         2.978489
# 3688  28481 David Cliffs Suite 023\r\nMckinneyhaven,...         7.099364
# 3691         1314 Lewis Ville\r\nLewischester, IA 69543         3.663287
# 3746    851 Hensley Springs\r\nEast Taraburgh, SC 56274        11.085472
# 3795          7655 Cohen Ferry\r\nWest Andrew, NY 77223        13.212439
# 3826        4694 Williams Islands\r\nEricberg, NE 76541        14.285598
# 3854  73014 Carlson Bypass Suite 457\r\nNicholasburg...         1.128142
# 3951  74491 Summer Streets Suite 908\r\nPort Nancyha...         6.026228
#
#      pregnant  education-num     relationship  skewness_glucose  mean_glucose  \
# 678         f           14.0              NaN         10.504677     37.328125
# 724         f            NaN              NaN          0.113315    119.382812
# 1180        f            NaN              NaN          0.008937    147.070312
# 1238        f           14.0          Husband          0.188801    131.914062
# 1267        f            9.0              NaN          3.412679     88.570312
# 1489        f            7.0        Own-child          0.902591    104.492188
# 1679        f            NaN        Own-child         -0.136844    114.539062
# 1763        t           10.0    Not-in-family         -0.174616    129.171875
# 1862        f           13.0    Not-in-family          2.470420     86.382812
# 1960        f           10.0          Husband               NaN    138.765625
# 2005     TRUE            NaN        Unmarried          0.164212    104.593750
# 2170      NaN           10.0    Not-in-family          0.266472           NaN
# 2233        f           16.0              NaN         11.012415     62.960938
# 2257      NaN            9.0        Unmarried         -0.344998    134.101562
# 2774      NaN         1200.0          Husband          0.986711    111.554688
# 2848        f           13.0          Husband               NaN     61.460938
# 2944        f            6.0    Not-in-family          1.033181    109.781250
# 2955        f            9.0        Unmarried         -0.334631    120.453125
# 3019        f            9.0          Husband         -0.395129           NaN
# 3098    FALSE            7.0          Husband               NaN           NaN
# 3103        t            9.0        Unmarried         -0.312486    124.914062
# 3170        f            NaN   Other-relative          0.682166           NaN
# 3257      NaN           10.0              NaN         -0.265950    136.117188
# 3527        f            5.0        Own-child          0.984387    122.476562
# 3683        f           14.0          Husband               NaN     42.976562
# 3688        f            7.0    Not-in-family          1.544753           NaN
# 3691      NaN            3.0          Husband          5.557122     72.054688
# 3746        f            9.0    Not-in-family          0.895623    110.070312
# 3795        f            6.0              NaN         -0.222749    109.453125
# 3826        f            9.0          Husband          1.205499    103.390625
# 3854        F            6.0        Unmarried         28.060145     28.343750
# 3951        f            9.0        Own-child          0.060912    106.718750
#
#       std_oxygen  capital-gain  skewness_oxygen  kurtosis_glucose  \
# 678    50.972282           NaN         0.495303          3.217384
# 724    29.767589           0.0        28.299804          0.133799
# 1180         NaN           0.0       297.847944         -0.417425
# 1238   37.953457           0.0        23.276103         -0.071573
# 1267   12.610148           0.0       210.857105          0.666299
# 1489         NaN           0.0        70.134399          0.290824
# 1679   26.479784           0.0        37.411527          0.208169
# 1763   34.033077           0.0        29.891930          0.133561
# 1862   59.924696           0.0         3.483176          1.373406
# 1960         NaN           0.0        33.735699          0.070280
# 2005   12.207188           NaN       210.055435          0.425018
# 2170         NaN           0.0        45.739782          0.264827
# 2233   65.572064           0.0         1.130669          2.622389
# 2257   12.020265           0.0              NaN         -0.122879
# 2774   19.855912           0.0        95.725134               NaN
# 2848         NaN           0.0              NaN          2.539502
# 2944   17.753278           0.0        55.816490          0.537863
# 2955   51.210491           0.0              NaN         -0.049047
# 3019         NaN           0.0       103.261706         -0.095445
# 3098    9.914319           0.0       379.587558         -0.076598
# 3103   21.543269           0.0        69.773978          0.004720
# 3170         NaN           0.0       125.782096          0.326218
# 3257   26.149560           0.0        41.945047          0.001149
# 3527   24.140423           0.0        61.494198          0.284663
# 3683   54.331824           0.0         7.470024               NaN
# 3688         NaN           0.0        52.461228               NaN
# 3691   42.820002           0.0        13.102997          1.649153
# 3746   13.524171           0.0       151.951658          0.210934
# 3795   11.170976           0.0       245.080261          0.090754
# 3826   10.583665           0.0       290.415072          0.253561
# 3854   71.163285           0.0         0.326351          4.818365
# 3951   29.929925           0.0        38.468864          0.483138
#
#                                           personal_info      education  \
# 678   Prof-specialty|United-States\r\r\nMarried-civ-...        Masters
# 724   Adm_clerical|United-States\r\r\n?? -- Self-emp...   Some-college
# 1180  Machine-op-inspct|United-States\r\r\nMarried-c...           11th
# 1238  Protective-serv|United-States\r\r\nMarried-civ...            NaN
# 1267  Craft-repair|United-States\r\r\nNever-married ...        HS-grad
# 1489  Craft-repair|Haiti\r\r\nNever-married -- Priva...           11th
# 1679  Prof_specialty|United-States\r\r\nNever-marrie...      Bachelors
# 1763  Other-service|United-States\r\r\nNever-married...   Some-college
# 1862  Handlers-cleaners|United-States\r\r\nNever-mar...      Bachelors
# 1960  Other-service|United-States\r\r\nMarried-civ-s...   Some-college
# 2005  Machine-op-inspct|United-States\r\r\nWidowed -...        5th-6th
# 2170  Other-service|United-States\r\r\nNever-married...   Some-college
# 2233  Adm-clerical|United-States\r\r\nNever-married ...      Doctorate
# 2257  Adm-clerical|United-States\r\r\nSeparated -- P...        HS-grad
# 2774  Transport-moving|United-States\r\r\nMarried-ci...     Assoc-acdm
# 2848  Farming-fishing|United-States\r\r\nMarried-civ...      Bachelors
# 2944  Sales|United-States\r\r\nNever-married -- Priv...           10th
# 2955  Other-service|United-States\r\r\nDivorced -- P...        HS-grad
# 3019  Machine-op-inspct|United-States\r\r\nMarried-c...        HS-grad
# 3098  Craft-repair|United-States\r\r\nMarried-civ-sp...           11th
# 3103  Sales|United-States\r\r\nDivorced -- Private|W...        HS-grad
# 3170  Sales|United-States\r\r\nNever-married -- priv...        HS-grad
# 3257  Other-service|?\r\r\nNever-married -- Private|...   Some-college
# 3527  Craft-repair|United-States\r\r\nNever-married ...            9th
# 3683  Exec-managerial|United-States\r\r\nMarried-civ...        Masters
# 3688  Other-service|United-States\r\r\nDivorced -- P...           11th
# 3691  Transport-moving|Mexico\r\r\nnan -- Private|White        5th-6th
# 3746  Other-service|United-States\r\r\nNever-married...        HS-grad
# 3795      ?|United-States\r\r\nNever-married -- ?|White           10th
# 3826  Machine-op-inspct|United-States\r\r\nMarried-c...        HS-grad
# 3854  Other-service|United-States\r\r\nWidowed -- Pr...           10th
# 3951  Adm_clerical|United-States\r\r\nNever-married ...        HS-grad
#
#         fnlwgt  class  std_glucose  income  mean_oxygen  hours-per-week  \
# 678        NaN    1.0    43.897806   <=50K   107.102007            55.0
# 724    71676.0    NaN          NaN     NaN     6.417224             1.0
# 1180  167065.0    0.0    45.582032     NaN     0.820234             NaN
# 1238  186539.0    0.0    44.490172    >50K     8.064381            40.0
# 1267   36275.0    0.0    33.858779   <=50K          NaN             NaN
# 1489  267034.0    0.0    40.074929   <=50K          NaN            40.0
# 1679  184589.0    0.0    51.280616   <=50K     5.801839            21.0
# 1763  149637.0    0.0    51.540201     NaN          NaN            40.0
# 1862  202046.0    1.0    46.733640   <=50K    27.238294            40.0
# 1960  123218.0    NaN    54.564968   <=50K     5.337793            40.0
# 2005       NaN    NaN    52.058777   <=50K     1.454013            40.0
# 2170  213385.0    0.0    48.416223   <=50K     4.383779            20.0
# 2233  220754.0    NaN    33.977337     NaN    48.867057            40.0
# 2257  228406.0    0.0    52.811404   <=50K     2.128763            40.0
# 2774  498325.0    NaN    40.337600   <=50K     2.360368            50.0
# 2848  249935.0    NaN    33.785376   <=50K     9.411371            60.0
# 2944  156822.0    0.0    40.253870   <=50K     3.626254            25.0
# 2955   83727.0    0.0          NaN   <=50K    18.691472            48.0
# 3019  175127.0    0.0    48.568711   <=50K          NaN            40.0
# 3098  259688.0    NaN    52.188426   <=50K     1.085284            50.0
# 3103   29059.0    0.0    47.858520   <=50K     3.724916            25.0
# 3170  194901.0    0.0    42.375426   <=50K     1.753344            40.0
# 3257  120691.0    NaN    50.573526     NaN     5.474080            35.0
# 3527   25955.0    0.0    41.549474   <=50K     3.428930             NaN
# 3683  119098.0    1.0    30.032395   <=50K    18.101171            40.0
# 3688  187969.0    0.0          NaN   <=50K     3.816054             NaN
# 3691       NaN    1.0    37.433964   <=50K    12.616221            40.0
# 3746  195985.0    0.0    40.339610     NaN          NaN            50.0
# 3795  634226.0    0.0    50.376994   <=50K     1.645485            17.0
# 3826  136081.0    0.0    38.801223   <=50K     1.484114            40.0
# 3854       NaN    NaN    31.814019   <=50K    57.377090            40.0
# 3951       NaN    1.0    48.599919   <=50K     6.269231            40.0
#
#       capital-loss
# 678            0.0
# 724         1944.0
# 1180           0.0
# 1238           NaN
# 1267           0.0
# 1489           0.0
# 1679           0.0
# 1763           NaN
# 1862        2001.0
# 1960           NaN
# 2005           0.0
# 2170           0.0
# 2233           0.0
# 2257           0.0
# 2774           NaN
# 2848           0.0
# 2944        1762.0
# 2955           0.0
# 3019           0.0
# 3098           0.0
# 3103        2754.0
# 3170           0.0
# 3257           0.0
# 3527           0.0
# 3683           NaN
# 3688           0.0
# 3691           0.0
# 3746           0.0
# 3795           0.0
# 3826        2051.0
# 3854           0.0
# 3951           0.0

# %% [markdown]
# Vidíme, že súbor personal_data určite neobsahuje duplikáty, počet všetkých záznamov je 3933 a počet unikátnych hodnôt
# pre meno a adresu je rovnaký. Každý záznam teda môžeme priradiť k jednému človeku. V súbore medical_data sa duplikáty
# už vyskytujú, vidíme, že počet unikátnych hodnôt pre meno a adresu je 3933, zatiaľ čo počet všetkých hodnôt je 3983.
# Ak záznam definitívne označíme za duplicitný, môžeme ho z dátoveho setu odstrániť. Predtým je ale nutné overiť, či sa
# skutočne jedná o duplikát.
#
# 100% duplicitné riadky sa v súbore nevyskytujú, rovnaké hodnoty nadobúdajú len v niektorých stĺpcoch. Počet riadkov, kde
# nie je unikátne meno a adresa je 50, ale ak zahrnieme aj stĺpec personal_info, tak sa zníži na 41. Zahrnutím stĺpca
# education klesne na 32. Treba vybrať stĺpce, podľa ktorých budeme určovať, či ide o duplikát a či nie. Zisťovať len
# podľa stĺpcov name a address nie je vhodné, keďže na rovnakej adrese môžu bývať aj dvaja ľudia s rovnakým menom. Bolo by
# vhodné pridať viacej stĺpcov, ktoré nám pomôžu zistiť, či je daný záznam skutočne duplikátom. Na to môžeme použiť
# napríklad stĺpec personal_info, ktorý obsahuje rôzne údaje, ako napríklad zamestnanie a rodinný stav. Vďaka tomu vieme
# povedať, že daný riadok sa vzťahuje na rozdielnu osobu a nie je duplicitný.

# %%
medical_data.pregnant.unique()
# Out:
# array(['f', 'FALSE', 'F', 'TRUE', 'T', 't', nan], dtype=object)

# %% [markdown]
# Na určenie tehotenstva je použitých zbytočne veľa hodnôt ('f', 'FALSE', 'F', 'TRUE', 'T', 't', nan), ktoré symbolizujú
# len dva stavy (nerátajúc 'NaN' hodnoty, ktoré sú prázdne). Bude nutné niektoré z nich premenovať, a používať len znaky
# T a F (alebo 1 a 0), prípadne zmeniť dátový typ celého stĺpca na bool.

# %%
medical_data.isnull().sum()
# Out:
# Unnamed: 0            0
# name                  0
# address               0
# kurtosis_oxygen       9
# pregnant             12
# education-num       404
# relationship         22
# skewness_glucose     18
# mean_glucose         20
# std_oxygen           16
# capital-gain         14
# skewness_oxygen       8
# kurtosis_glucose     15
# personal_info         9
# education            12
# fnlwgt               16
# class                21
# std_glucose          15
# income               14
# mean_oxygen          12
# hours-per-week       13
# capital-loss         13
# dtype: int64

# %% [markdown]
# V súbore other_train.cvs sa vyskytujú záznamy, kde majú niektoré stĺpce chýbajúcu hodnotu reprezentovanú stavom NaN.
# Ak sa nulová hodnota vyskytuje v dole uvedených stĺpcoch, nejde o príliš závažný problém, keďže tie stĺpce neobsahujú
# pre nás dôležité informácie. Dané hodnoty môžeme nechať naďalej prázdne, keďže sa zväčša jedná o údaje, ktorých hodnotu
# nevieme predpokladať, takže sa nedá doplniť. Ak pri ďalšej práci narazíme na záznam, kde bude v stĺpci, ktorý potrebuje
# použiť, nulová hodnota, tak daný záznam jednoducho nezarátame.
#
# Ďalšie z možných riešení je na miesto chýbajúcej hodnoty doplniť priemer, alebo medián. Toto je vhodné použiť v prípadoch,
# kde hodnotu nevieme predpokladať. Samozrejme, dá sa to len pri číselných údajoch, ak sa jedná o dáta iného typu, je nutné
# použiť najčastejšie vyskytujúcu sa hodnotu.
#
# Stĺpce, kde môžeme nulovú hodnotu ignorovať:
# - pregnant
# - education-num
# - relationship
# - capital-gain
# - personal_info
# - education
# - fnlwgt
# - income
# - hours-per-week
# - capital-loss
#
# V nasledujúcich stĺpcoch predstavuje chýbajúca hodnota vážnejší problém, keďže sa jedná o stĺpce, ktoré budú pre
# nastávajúcu prácu podstatnejšie. V tomto prípade by bolo možné v niektorých prípadoch chýbajúce hodnoty doplniť.
# Môžeme porovnať vybrané neprázdne stĺpce s neprázdnymi stĺpcami ostatných záznamov. Ak v inom zázname nájdeme podobné
# hodnoty, dá sa predpokladať, že chýbajúca hodnota pôvodného záznamu, bude podobná tej v nájdenom. Samozrejme, táto
# hodnota nebude 100% presná, preto je nutné brať ju s rezervou. Toto je možné len v prípadoch, keď k stĺpcu s chýbajucou
# hodnotou, vieme priradiť stĺpec, ktorých hodnoty spolu súvisia.
#
# Stĺpce, kde môžeme predpokladať hodnotu chýbajúcich údajov:
# - kurtosis_oxygen
# - skewness_glucose
# - mean_glucose
# - std_oxygen
# - skewness_oxygen
# - kurtosis_glucose
# - class
# - std_glucose
# - mean_oxygen

# %%
sns.displot(medical_data, x = "mean_oxygen")

# %% [markdown]
# Ako môžeme v hore uvedenom grafe vidieť, stĺpec "mean_oxygen" v niektorých záznamoch nadobúda výrazne vychýlené hodnoty.
# Daný problém nemôžeme vyriešiť spôsobom, kde vychýleným hodnotám pripíšeme hodnotu priemeru, keďže extrémne vysoké (alebo
# aj nízke) hodnoty výsledný priemer ovplyvňujú. V tomto prípade je vhodné použiť medián, ktorý takýmito hodnotami zväčša
# ovplyvnený nebýva. Takto sa môžeme vysporiadať so všetkými záznamami, ktoré budú obsahovať výrazne vychýlené hodnoty.
# Iným riešením by bolo vyrátať priemer všetkých záznamov, kde je ich hodnota v norme, a priradiť ho vychýleným hodnotám.
# Na zistenie vychýlenej hodnoty nemusíme používať len grafy, funkcia describe() nám ukáže všetky dôležité štatistické
# údaje. Ak je maximum/minimum výrazne väčšie ako horný/dolný kvartil, dá sa predpokladať, že niektoré hodnoty sú vychýlené.
